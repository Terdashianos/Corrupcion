# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm 

# %matplotlib inline

# %%
df = pd.read_csv("clusters.csv")
df.head()
# Out:
#    Unnamed: 0    expediente autoridadSancionadora              sancion  \
# 0           0  EXP/e54203a9                   OIC  ACTA ADMINISTRATIVA
# 1           1  EXP/e54203a9                   OIC  ACTA ADMINISTRATIVA
# 2           2  EXP/e54203a9                   OIC  ACTA ADMINISTRATIVA
# 3           3  EXP/e54203a9                   OIC  ACTA ADMINISTRATIVA
# 4           4  EXP/e54203a9                   OIC  ACTA ADMINISTRATIVA
#
#                 causa                               dependencia  \
# 0  ABUSO DE FUNCIONES  SECRETARIA DE HACIENDA Y CREDITO PUBLICO
# 1  ABUSO DE FUNCIONES  SECRETARIA DE HACIENDA Y CREDITO PUBLICO
# 2  ABUSO DE FUNCIONES  SECRETARIA DE HACIENDA Y CREDITO PUBLICO
# 3  ABUSO DE FUNCIONES  SECRETARIA DE HACIENDA Y CREDITO PUBLICO
# 4  ABUSO DE FUNCIONES  SECRETARIA DE HACIENDA Y CREDITO PUBLICO
#
#                  curp    genero                    puesto  \
# 0  TAKV710225HVZFDR01  FEMENINO  Secretario/a de Estado A
# ...

# %%
columns_names = df.columns.values
print(columns_names)
# Out:
# ['Unnamed: 0' 'expediente' 'autoridadSancionadora' 'sancion' 'causa'
#  'dependencia' 'curp' 'genero' 'puesto' 'falta' 'multa' 'inhabilitacion'
#  'institucion' 'completa' 'escolaridad' 'experiencia' 'ingreso' 'moneda']

# %%
multas = df[['autoridadSancionadora', 'sancion', 'causa', 'dependencia', 'genero', 'puesto', "multa", "ingreso"]]

# %%
multas['causa'] = multas['causa'].map({"ABUSO DE FUNCIONES":"ABUSO DE FUNCIONES",
                                      "DESVÍO DE RECURSOS PÚBLICOS":"DESVÍO DE RECURSOS PÚBLICOS",
                                      "TRÁFICO DE INFLUENCIAS":"TRÁFICO DE INFLUENCIAS",
                                      "UTILIZACIÓN INDEBIDA DE INFORMACIÓN":"UTILIZACIÓN INDEBIDA DE INFORMACIÓN",
                                      "CONFLICTO DE INTERÉS":"CONFLICTO DE INTERÉS",
                                      "COHECHO, ACEPTO BENEFICIO NO COMPRENDIDO EN SU REMUNERACIÓN COMO PERSONA SERVIDORA PÚBLICA":"COHECHO",
                                      "PECULADO, AUTORIZO ACTOS PARA EL USO O APROPIACIÓN PARA SÍ DE RECURSOS PÚBLICOS SIN FUNDAMENTOS JURÍDICOS":"PECULADO",
                                      "NEPOTISMO":"NEPOTISMO",
                                      "ENRIQUECIMIENTO OCULTO":"ENRIQUECIMIENTO OCULTO",
                                      "CONTRATACIÓN INDEBIDA":"CONTRATACIÓN INDEBIDA"
                                        })
multas['genero'] = multas['genero'].map({"FEMENINO":"Mujer",
                                       "MASCULINO":"Hombre"
                                        })

multas['dependencia'] = multas['dependencia'].map({'SECRETARIA DE HACIENDA Y CREDITO PUBLICO':'Gasto Público',
 'CONSEJO DE PROMOCION TURISTICA DE MEXICO S.A. DE C.V.':'Servicios',
 'ADMINISTRACION PORTUARIA INTEGRAL DE ENSENADA S.A. DE C.V.':'Servicios',
 'CENTRO DE INVESTIGACION CIENTIFICA DE YUCATAN A.C.':'Educación e Investigación',
 'SECRETARIA DE MEDIO AMBIENTE Y RECURSOS NATURALES':'Medio Ambiente',
 'REGISTRO AGRARIO NACIONAL':'Agricultura',
 'SECRETARIA DE AGRICULTURA GANADERIA DESARROLLO RURAL PESCA Y ALIMENTACION':'Agricultura',
 'COMISION NACIONAL DE LIBROS DE TEXTO GRATUITOS':'Educación e Investigación',
 'SERVICIOS DE ALMACENAMIENTO DEL NORTE S.A.':'Servicios',
 'COMISION NACIONAL PARA EL USO EFICIENTE DE LA ENERGIA':'Energía',
 'CENTRO DE INVESTIGACION Y SEGURIDAD NACIONAL':'Seguridad Nacional',
 'ADMINISTRACION PORTUARIA INTEGRAL DE COATZACOALCOS S.A. DE C.V.':'Comunicación y Transporte',
 'COMISION NACIONAL BANCARIA Y DE VALORES':'Banca y Finanzas',
 'ARCHIVO GENERAL DE LA NACION':'Gobernanza y Justicia',
 'ADMINISTRACION PORTUARIA INTEGRAL DE LAZARO CARDENAS S.A. DE C.V.':'Comunicación y Transporte',
 'INSTITUTO NACIONAL DE CARDIOLOGIA IGNACIO CHAVEZ':'Salud',
 'INSTITUTO NACIONAL DE INVESTIGACIONES NUCLEARES':'Energía',
 'FIDEICOMISO DE FOMENTO MINERO':'Minería',
 'CENTRO NACIONAL DE EQUIDAD DE GENERO Y SALUD REPRODUCTIVA':'Salud',
 'ADMINISTRACION FEDERAL DE SERVICIOS EDUCATIVOS EN EL DISTRITO FEDERAL':'Educación e Investigación',
 'ADMINISTRACION PORTUARIA INTEGRAL DE TAMPICO S.A. DE C.V.':'Comunicación y Transporte',
 'COMISION NACIONAL DE ARBITRAJE MEDICO':'Salud',
 'CORPORACIÓN ÁNGELES VERDES':'Salud',
 'ADMINISTRACION PORTUARIA INTEGRAL DE VERACRUZ S.A. DE C.V.':'Servicios',
 'CFE GENERACIÓN III':'Energía',
 'TRANSPORTADORA DE SAL S.A. DE C.V.':'Comunicación y Transporte',
 'AGROASEMEX S.A.':'Agricultura',
 'INSTITUTO MATIAS ROMERO DE ESTUDIOS DIPLOMATICOS':'Educación e Investigación',
 'AGENCIA NACIONAL DE SEGURIDAD INDUSTRIAL Y DE PROTECCIÓN AL MEDIO AMBIENTE DEL SECTOR HIDROCARBUROS':'Industria',
 'PROCURADURIA FEDERAL DEL CONSUMIDOR':'Economía y Desarrollo',
 'COMISION PARA PREVENIR Y ERRADICAR LA VIOLENCIA CONTRA LAS MUJERES':'Seguridad Nacional',
 'COLEGIO SUPERIOR AGROPECUARIO DEL ESTADO DE GUERRERO':'Educación e Investigación',
 'EL COLEGIO DE MEXICO A.C.':'Educación e Investigación',
 'CIATEQ A.C. CENTRO DE TECNOLOGIA AVANZADA':'Educación e Investigación',
 'AEROPUERTOS Y SERVICIOS AUXILIARES':'Servicios',
 'FIDEICOMISO PROMEXICO':'Banca y Finanzas',
 'COMISION NACIONAL DE AREAS NATURALES PROTEGIDAS':'Medio Ambiente',
 'SERVICIO GEOLOGICO MEXICANO':'Educación e Investigación',
 'HOSPITAL REGIONAL DE ALTA ESPECIALIDAD DEL BAJIO':'Salud',
 'COMPAÑIA MEXICANA DE EXPLORACIONES S.A. DE C.V.':'Educación e Investigación',
 'COMISION NACIONAL DE LAS ZONAS ARIDAS':'Educación e Investigación',
 'ADMINISTRACION PORTUARIA INTEGRAL DE MANZANILLO S.A. DE C.V.':'Comunicación y Transporte',
 'TRIBUNAL FEDERAL DE CONCILIACION Y ARBITRAJE':'Servicios',
 'SERVICIOS AEROPORTUARIOS DE LA CIUDAD DE MEXICO S.A. DE C.V.':'Comunicación y Transporte',
 'FONDO DE OPERACION Y FINANCIAMIENTO BANCARIO A LA VIVIENDA':'Banca y Finanzas',
 'FIDEICOMISO DE RIESGO COMPARTIDO':'Banca y Finanzas',
 'PEMEX-REFINACION':'Energía',
 'FONDO NACIONAL DE FOMENTO AL TURISMO':'Servicios',
 'ADMINISTRACION PORTUARIA INTEGRAL DE DOS BOCAS S.A. DE C.V.':'Comunicación y Transporte',
 'ADMINISTRACION PORTUARIA INTEGRAL DE ALTAMIRA S.A. DE C.V.':'Comunicación y Transporte',
 'FONDO ESPECIAL DE ASISTENCIA TECNICA Y GARANTIA PARA LOS CREDITOS AGROPECUARIOS':'Banca y Finanzas',
 'INSTITUTO DE SEGURIDAD SOCIAL PARA LAS FUERZAS ARMADAS MEXICANAS':'Salud',
 'INSTITUTO NACIONAL DE GERIATRÍA':'Salud',
 'LABORATORIOS DE BIOLOGICOS Y REACTIVOS DE MEXICO S.A. DE C.V.':'Salud',
 'CENTRO DE INVESTIGACIONES Y ESTUDIOS SUPERIORES EN ANTROPOLOGIA SOCIAL':'Educación e Investigación',
 'CFE SUMINISTRADOR DE SERVICIOS BÁSICOS':'Energía',
 'COMPAÑIA OPERADORA DEL CENTRO CULTURAL Y TURISTICO DE TIJUANA S.A. DE C.V.':'Arte y Cultura',
 'CENTRO DE INVESTIGACIONES BIOLOGICAS DEL NOROESTE S.C.':'Educación e Investigación',
 'CENTRO NACIONAL DE EXCELENCIA TECNOLOGICA EN SALUD':'Salud',
 'CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS DEL INSTITUTO POLITECNICO NACIONAL':'Educación e Investigación',
 'I.I.I. SERVICIOS S.A. DE C.V.':'Servicios',
 'ADMINISTRACION PORTUARIA INTEGRAL DE PROGRESO S.A. DE C.V.':'Comunicación y Transporte',
 'CENTRO DE INVESTIGACION Y ASISTENCIA EN TECNOLOGIA Y DISEÑO DEL ESTADO DE JALISCO A.C.':'Educación e Investigación',
 'UNIVERSIDAD AUTONOMA METROPOLITANA':'Educación e Investigación',
 'INSTITUTO POTOSINO DE INVESTIGACION CIENTIFICA Y TECNOLOGICA A.C.':'Educación e Investigación',
 'CENTRO NACIONAL DE TRASPLANTES':'Salud',
 'CENTRO NACIONAL DE METROLOGIA':'Medio Ambiente',
 'CONSEJO NACIONAL DE CIENCIA Y TECNOLOGIA':'Educación e Investigación',
 'SECRETARIA DE TURISMO':'Servicios',
 'INSTITUTO NACIONAL DE LAS PERSONAS ADULTAS MAYORES':'Salud',
 'HOSPITAL REGIONAL DE ALTA ESPECIALIDAD DE OAXACA':'Salud',
 'EL COLEGIO DE LA FRONTERA NORTE A.C.':'Educación e Investigación',
 'UNIVERSIDAD ABIERTA Y A DISTANCIA DE MÉXICO':'Educación e Investigación',
 'FONATUR PRESTADORA DE SERVICIOS S.A. DE C.V.':'Servicios',
 'CENTRO DE PRODUCCION DE PROGRAMAS INFORMATIVOS Y ESPECIALES':'Servicios',
 'ADMINISTRACION PORTUARIA INTEGRAL DE MAZATLAN S.A. DE C.V.':'Comunicación y Transporte',
 'INSTITUTO NACIONAL DE LAS MUJERES':'Seguridad Nacional',
 'CENTRO NACIONAL PARA LA PREVENCIÓN Y EL CONTROL DE LAS ADICCIONES':'Salud',
 'SECRETARIA DE RELACIONES EXTERIORES':'Gobernanza y Justicia',
 'CENTRO DE INVESTIGACION EN GEOGRAFIA Y GEOMATICA ING. JORGE L. TAMAYO A.C.':'Educación e Investigación',
 'PROCURADURIA GENERAL DE LA REPUBLICA':'Gobernanza y Justicia',
 'CENTRO DE INVESTIGACION CIENTIFICA Y DE EDUCACION SUPERIOR DE ENSENADA B.C.':'Educación e Investigación',
 'SERVICIOS A LA NAVEGACION EN EL ESPACIO AEREO MEXICANO':'Educación e Investigación',
 'INSTITUTO NACIONAL DE ASTROFISICA OPTICA Y ELECTRONICA':'Educación e Investigación',
 'COORDINACION GENERAL DE LA COMISION MEXICANA DE AYUDA A REFUGIADOS':'Salud',
 'INSTITUTO NACIONAL DE DESARROLLO SOCIAL':'Economía y Desarrollo',
 'INSTITUTO FEDERAL DE TELECOMUNICACIONES':'Comunicación y Transporte',
 'SERVICIO NACIONAL DE INSPECCION Y CERTIFICACION DE SEMILLAS':'Agricultura',
 'COMISION PARA LA REGULARIZACION DE LA TENENCIA DE LA TIERRA':'Gobernanza y Justicia',
 'INSTITUTO DEL FONDO NACIONAL PARA EL CONSUMO DE LOS TRABAJADORES':'Banca y Finanzas',
 'SECRETARIA DE GOBERNACION':'Gobernanza y Justicia',
 'CENTRO NACIONAL DE CONTROL DE GAS NATURAL':'Energía',
 'CAMINOS Y PUENTES FEDERALES DE INGRESOS Y SERVICIOS CONEXOS':'Comunicación y Transporte',
 'XE-IPN CANAL 11':'Comunicación y Transporte',
 'FONDO DE GARANTIA Y FOMENTO PARA LA AGRICULTURA GANADERIA Y AVICULTURA':'Agricultura',
 'INSTITUTO POLITECNICO NACIONAL':'Educación e Investigación',
 'INSTITUTO MEXICANO DEL TRANSPORTE':'Comunicación y Transporte',
 'SOCIEDAD HIPOTECARIA FEDERAL S.N.C.':'Banca y Finanzas',
 'CENTRO NACIONAL DE VIGILANCIA EPIDEMIOLOGICA Y CONTRTOL DE ENFERMEDADES':'Salud',
 'AUTORIDAD FEDERAL PARA EL DESARROLLO DE LAS ZONAS ECONÓMICAS ESPECIALES':'Economía y Desarrollo',
 'CONSEJO NACIONAL DE FOMENTO EDUCATIVO':'Educación e Investigación',
 'CENTRO NACIONAL PARA LA PREVENCION Y CONTROL DEL VIH/SIDA':'Salud',
 'EDUCAL S.A. DE C.V.':'Educación e Investigación',
 'SISTEMA NACIONAL PARA EL DESARROLLO INTEGRAL DE LA FAMILIA':'Salud',
 'CONSEJO NACIONAL PARA LA CULTURA Y LAS ARTES':'Arte y Cultura',
 'COMISION NACIONAL DE VIVIENDA':'Economía y Desarrollo',
 'INSTITUTO NACIONAL DE LENGUAS INDIGENAS':'Economía y Desarrollo',
 'CENTRO DE INVESTIGACION EN MATEMATICAS A.C.':'Educación e Investigación',
 'CENTRO DE INGENIERIA Y DESARROLLO INDUSTRIAL':'Industria',
 'CENTRO DE EVALUACION Y DESARROLLO HUMANO':'Educación e Investigación',
 'HOSPITAL INFANTIL DE MEXICO FEDERICO GOMEZ':'Salud'
})
# Out:
# C:\Users\syste\AppData\Local\Temp/ipykernel_12244/368489914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multas['causa'] = multas['causa'].map({"ABUSO DE FUNCIONES":"ABUSO DE FUNCIONES",
# C:\Users\syste\AppData\Local\Temp/ipykernel_12244/368489914.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multas['genero'] = multas['genero'].map({"FEMENINO":"Mujer",
# C:\Users\syste\AppData\Local\Temp/ipykernel_12244/368489914.py:16: SettingWithCopyWarning:
# ...

# %%
multas = multas.fillna(method ='ffill') 
multas = multas.dropna(axis=0)
multas.isnull().sum().sort_values(ascending=False)
# Out:
# autoridadSancionadora    0
# sancion                  0
# causa                    0
# dependencia              0
# genero                   0
# puesto                   0
# multa                    0
# ingreso                  0
# dtype: int64

# %%
multas["value"]=1
multas.head()
# Out:
#    autoridadSancionadora  sancion                        causa dependencia  \
# 8               Tribunal  MULTADO  DESVÍO DE RECURSOS PÚBLICOS   Servicios
# 9               Tribunal  MULTADO  DESVÍO DE RECURSOS PÚBLICOS   Servicios
# 10              Tribunal  MULTADO  DESVÍO DE RECURSOS PÚBLICOS   Servicios
# 11              Tribunal  MULTADO  DESVÍO DE RECURSOS PÚBLICOS   Servicios
# 12              Tribunal  MULTADO  DESVÍO DE RECURSOS PÚBLICOS   Servicios
#
#     genero                puesto    multa   ingreso  value
# 8   Hombre  Jefe de Departamento  25245.0  126855.0      1
# 9   Hombre  Jefe de Departamento  25245.0  608904.0      1
# 10  Hombre  Jefe de Departamento  25245.0  608904.0      1
# 11  Hombre  Jefe de Departamento  25245.0  608904.0      1
# 12  Hombre  Jefe de Departamento  25245.0  608904.0      1

# %%
multas.to_csv("multas_shiny.csv")

# %% [markdown]
# # Inabilitaciones

# %%
df_2 = pd.read_csv("sanciones_inhabilitacion.csv")
df_2.head()
# Out:
#    Unnamed: 0        expediente      autoridadSancionadora       sancion  \
# 0           2     SANC/23af791f        Contraloría Interna  INHABILITADO
# 1           5  ARCHIVO/d9986c19                   Tribunal  INHABILITADO
# 2           7  ARCHIVO/2d4bb61d  Organo de Control Interno    SUSPENSION
# 3          11  CARPETA/bb6be9b6                   Tribunal  INHABILITADO
# 4          12      EXP/ef50ba30                        OIC  INHABILITADO
#
#                          causa                       dependencia  \
# 0       TRÁFICO DE INFLUENCIAS  Comisión Federal de Electricidad
# 1       ENRIQUECIMIENTO OCULTO  Comisión Federal de Electricidad
# 2       TRÁFICO DE INFLUENCIAS  Comisión Federal de Electricidad
# 3                    NEPOTISMO  Comisión Federal de Electricidad
# 4  DESVÍO DE RECURSOS PÚBLICOS  Comisión Federal de Electricidad
#
#                  curp     genero                puesto  \
# 0  GAER730906MVZSHC05   FEMENINO  Jefe de departamento
# ...

# %%
columns_names = df_2.columns.values
print(columns_names)
# Out:
# ['Unnamed: 0' 'expediente' 'autoridadSancionadora' 'sancion' 'causa'
#  'dependencia' 'curp' 'genero' 'puesto' 'falta' 'multa' 'inhabilitacion']

# %%
df_2=df_2[['autoridadSancionadora', 'sancion', 'causa', 'dependencia', 'genero', 'puesto', 'inhabilitacion']]
df_2["value"]=1
df_2.head()
# Out:
#        autoridadSancionadora       sancion                        causa  \
# 0        Contraloría Interna  INHABILITADO       TRÁFICO DE INFLUENCIAS
# 1                   Tribunal  INHABILITADO       ENRIQUECIMIENTO OCULTO
# 2  Organo de Control Interno    SUSPENSION       TRÁFICO DE INFLUENCIAS
# 3                   Tribunal  INHABILITADO                    NEPOTISMO
# 4                        OIC  INHABILITADO  DESVÍO DE RECURSOS PÚBLICOS
#
#                         dependencia     genero                puesto  \
# 0  Comisión Federal de Electricidad   FEMENINO  Jefe de departamento
# 1  Comisión Federal de Electricidad  MASCULINO  Jefe de departamento
# 2  Comisión Federal de Electricidad  MASCULINO  Jefe de departamento
# 3  Comisión Federal de Electricidad   FEMENINO  Jefe de departamento
# 4  Comisión Federal de Electricidad   FEMENINO  Jefe de departamento
#
#   inhabilitacion  value
# 0         6 años      1
# 1         2 años      1
# 2         6 años      1
# ...

# %%
df_2['causa'].unique().tolist()
# Out:
# ['TRÁFICO DE INFLUENCIAS',
#  'ENRIQUECIMIENTO OCULTO',
#  'NEPOTISMO',
#  'DESVÍO DE RECURSOS PÚBLICOS',
#  'CONTRATACIÓN INDEBIDA',
#  'CONFLICTO DE INTERÉS',
#  'UTILIZACIÓN INDEBIDA DE INFORMACIÓN',
#  'COHECHO, ACEPTO BENEFICIO NO COMPRENDIDO EN SU REMUNERACIÓN COMO PERSONA SERVIDORA PÚBLICA',
#  'PECULADO, AUTORIZO ACTOS PARA EL USO O APROPIACIÓN PARA SÍ DE RECURSOS PÚBLICOS SIN FUNDAMENTOS JURÍDICOS',
#  'ABUSO DE FUNCIONES',
#  'LA EMPRESA PROPORCIONÓ INFORMACIÓN NO VERAZ',
#  'NO FORMALIZACION DE CONTRATO',
#  'NO HABER EXHIBIDO LA GARANTÍA DE CUMPLIMIENTO DENTRO DEL PLAZO ESTABLECIDO EN LA CONVOCATORIA DE CONFORMIDAD CON LO DISPUESTO EN LOS ARTÍCULOS 48 Y 49 DE LA LEY DE ADQUISICIONES, ARRENDAMIENTOS Y SERVICIOS DEL SECTOR PÚBLICO, POR LO QUE SE RECINDIÓ EL CONTRATO',
#  'NO ENTREGAR LA OBRA EN LA FECHA COMPROMETIDA',
#  'Abuso de funciones al ejercer su cargo']

# %%
df_2['causa'] = df_2['causa'].map({'TRÁFICO DE INFLUENCIAS':'TRÁFICO DE INFLUENCIAS',
 'ENRIQUECIMIENTO OCULTO':'ENRIQUECIMIENTO OCULTO',
 'NEPOTISMO':'NEPOTISMO',
 'DESVÍO DE RECURSOS PÚBLICOS':'DESVÍO DE RECURSOS PÚBLICOS',
 'CONTRATACIÓN INDEBIDA':'CONTRATACIÓN INDEBIDA',
 'CONFLICTO DE INTERÉS':'CONFLICTO DE INTERÉS',
 'UTILIZACIÓN INDEBIDA DE INFORMACIÓN':'UTILIZACIÓN INDEBIDA DE INFORMACIÓN',
 'COHECHO, ACEPTO BENEFICIO NO COMPRENDIDO EN SU REMUNERACIÓN COMO PERSONA SERVIDORA PÚBLICA':"COHECHO",
 'PECULADO, AUTORIZO ACTOS PARA EL USO O APROPIACIÓN PARA SÍ DE RECURSOS PÚBLICOS SIN FUNDAMENTOS JURÍDICOS':"PECULADO",
 'ABUSO DE FUNCIONES':'ABUSO DE FUNCIONES',
 'LA EMPRESA PROPORCIONÓ INFORMACIÓN NO VERAZ':"PROPORCIÓN DE INFORMACIÓN NO VERAZ",
 'NO FORMALIZACION DE CONTRATO':"NO FORMALIZACION DE CONTRATO",
 'NO HABER EXHIBIDO LA GARANTÍA DE CUMPLIMIENTO DENTRO DEL PLAZO ESTABLECIDO EN LA CONVOCATORIA DE CONFORMIDAD CON LO DISPUESTO EN LOS ARTÍCULOS 48 Y 49 DE LA LEY DE ADQUISICIONES, ARRENDAMIENTOS Y SERVICIOS DEL SECTOR PÚBLICO, POR LO QUE SE RECINDIÓ EL CONTRATO':"FALTA DE GARANTÍA DE CUMPLIMIENTO",
 'NO ENTREGAR LA OBRA EN LA FECHA COMPROMETIDA':"OBRA FUERA DE TIEMPO",
 'Abuso de funciones al ejercer su cargo':"ABUSO DE FUNCIONES"
                                        })
df_2['genero'] = df_2['genero'].map({"FEMENINO":"Mujer",
                                       "MASCULINO":"Hombre"
                                        })

df_2['dependencia'] = df_2['dependencia'].map({'Comisión Federal de Electricidad':'Energía',
 'SECRETARIA DE MEDIO AMBIENTE Y RECURSOS NATURALES':'Medio Ambiente',
 'SECRETARIA DE AGRICULTURA GANADERIA DESARROLLO RURAL PESCA Y ALIMENTACION':'Agricultura',
 'SERVICIOS DE ALMACENAMIENTO DEL NORTE S.A.':'Servicios',
 'COMISION NACIONAL PARA EL USO EFICIENTE DE LA ENERGIA':'Energía',
 'CENTRO DE INVESTIGACION Y SEGURIDAD NACIONAL':'Seguridad Nacional',
 'ADMINISTRACION PORTUARIA INTEGRAL DE COATZACOALCOS S.A. DE C.V.':'Comunicación y Transporte',
 'INSTITUTO NACIONAL DE CARDIOLOGIA IGNACIO CHAVEZ':'Salud',
 'INSTITUTO NACIONAL DE INVESTIGACIONES NUCLEARES':'Energía',
 'ADMINISTRACION FEDERAL DE SERVICIOS EDUCATIVOS EN EL DISTRITO FEDERAL':'Educación e Investigación',
 'ADMINISTRACION PORTUARIA INTEGRAL DE TAMPICO S.A. DE C.V.':'Comunicación y Transporte',
 'COMISION NACIONAL DE ARBITRAJE MEDICO':'Salud',
 'CORPORACIÓN ÁNGELES VERDES':'Salud',
 'ADMINISTRACION PORTUARIA INTEGRAL DE VERACRUZ S.A. DE C.V.':'Comunicación y Transporte',
 'TRANSPORTADORA DE SAL S.A. DE C.V.':'Comunicación y Transporte',
 'AGROASEMEX S.A.':'Agricultura',
 'INSTITUTO MATIAS ROMERO DE ESTUDIOS DIPLOMATICOS':'Educación e Investigación',
 'EL COLEGIO DE MEXICO A.C.':'Educación e Investigación',
 'INSTITUTO DE ECOLOGIA A.C. (INV)':'Medio Ambiente',
 'COMITÉ NACIONAL PARA EL DESARROLLO SUSTENTABLE DE LA CAÑA DE AZÚCAR':'Agricultura',
 'COMISION FEDERAL DE TELECOMUNICACIONES':'Comunicación y Transporte',
 'COMISION NACIONAL DE CULTURA FISICA Y DEPORTE':'Educación e Investigación',
 'LICONSA S.A. DE C.V.':'Agricultura',
 'SECRETARIA DE DESARROLLO AGRARIO TERRITORIAL Y URBANO':'Agricultura',
 'COLEGIO DE BACHILLERES':'Educación e Investigación',
 'PEMEX-GAS Y PETROQUIMICA BASICA':'Energía',
 'INSTITUTO FEDERAL DE ACCESO A LA INFORMACION PUBLICA':'Comunicación y Transporte',
 'SECRETARIA DE ENERGIA':'Energía',
 'PRESIDENCIA DE LA REPUBLICA':'Gobernanza y Justicia',
 'BANCO NACIONAL DE OBRAS Y SERVICIOS PUBLICOS S.N.C.':'Banca y Finanzas',
 'SECRETARIA DE DESARROLLO SOCIAL':'Economía y Desarrollo',
 'BANCO NACIONAL DE CREDITO RURAL S.N.C.':'Banca y Finanzas',
 'TALLERES GRAFICOS DE MEXICO':'Educación e Investigación',
 'CASA DE MONEDA DE MEXICO':'Banca y Finanzas',
 'CONSEJO NACIONAL PARA PREVENIR LA DISCRIMINACION':'Educación e Investigación',
 'FONDO NACIONAL PARA EL FOMENTO DE LAS ARTESANIAS':'Arte y Cultura',
 'COMISION NACIONAL DEL AGUA':'Medio Ambiente',
 'ADMINISTRACION PORTUARIA INTEGRAL DE SALINA CRUZ S.A. DE C.V.':'Comunicación y Transporte',
 'REGISTRO AGRARIO NACIONAL':'Agricultura',
 'CFE CORPORATIVO':'Energía',
 'COMISION NACIONAL DE ACUACULTURA Y PESCA':'Agricultura',
 'NOTIMEX S.A. DE C.V.':'Comunicación y Transporte',
 'APOYOS Y SERVICIOS A LA COMERCIALIZACION AGROPECUARIA':'Agricultura',
 'FIDEICOMISO FONDO DE CAPITALIZACION E INVERSION DEL SECTOR RURAL':'Banca y Finanzas',
 'CENTRO DE INVESTIGACION EN QUIMICA APLICADA':'Educación e Investigación',
 'INSTITUTO DE INVESTIGACIONES DR. JOSE MARIA LUIS MORA':'Educación e Investigación',
 'NOTIMEX AGENCIA DE NOTICIAS DEL ESTADO MEXICANO':'Comunicación y Transporte',
 'COMISION DE APELACION Y ARBITRAJE DEL DEPORTE':'Educación e Investigación',
 'FIDEICOMISO PARA LA CINETECA NACIONAL':'Arte y Cultura',
 'BANCO NACIONAL DE COMERCIO EXTERIOR S.N.C.':'Banca y Finanzas',
 'AGENCIA NACIONAL DE SEGURIDAD INDUSTRIAL Y DE PROTECCIÓN AL MEDIO AMBIENTE DEL SECTOR HIDROCARBUROS':'Industria',
 'UNIVERSIDAD PEDAGOGICA NACIONAL':'Educación e Investigación',
 'FONDO DE CULTURA ECONOMICA':'Economía y Desarrollo',
 'ADMINISTRACION PORTUARIA INTEGRAL DE MANZANILLO S.A. DE C.V.':'Comunicación y Transporte',
 'CENTRO NACIONAL DE EQUIDAD DE GENERO Y SALUD REPRODUCTIVA':'Salud',
 'SERVICIOS AEROPORTUARIOS DE LA CIUDAD DE MEXICO S.A. DE C.V.':'Comunicación y Transporte',
 'FIDEICOMISO DE RIESGO COMPARTIDO':'Banca y Finanzas',
 'ADMINISTRACION PORTUARIA INTEGRAL DE DOS BOCAS S.A. DE C.V.':'Comunicación y Transporte',
 'ADMINISTRACION PORTUARIA INTEGRAL DE ALTAMIRA S.A. DE C.V.':'Comunicación y Transporte',
 'FONDO ESPECIAL DE ASISTENCIA TECNICA Y GARANTIA PARA LOS CREDITOS AGROPECUARIOS':'Agricultura',
 'INSTITUTO DE SEGURIDAD SOCIAL PARA LAS FUERZAS ARMADAS MEXICANAS':'Salud',
 'INSTITUTO NACIONAL DE GERIATRÍA':'Salud',
 'CFE SUMINISTRADOR DE SERVICIOS BÁSICOS':'Energía',
 'CENTRO NACIONAL DE EXCELENCIA TECNOLOGICA EN SALUD':'Salud',
 'I.I.I. SERVICIOS S.A. DE C.V.':'Servicios',
 'ADMINISTRACION PORTUARIA INTEGRAL DE PROGRESO S.A. DE C.V.':'Comunicación y Transporte',
 'CENTRO DE INVESTIGACION Y ASISTENCIA EN TECNOLOGIA Y DISEÑO DEL ESTADO DE JALISCO A.C.':'Educación e Investigación',
 'HOSPITAL REGIONAL DE ALTA ESPECIALIDAD DE LA PENINSULA DE YUCATAN':'Salud',
 'INSTITUTO MEXICANO DE LA RADIO':'Comunicación y Transporte',
 'FONDO DE OPERACION Y FINANCIAMIENTO BANCARIO A LA VIVIENDA':'Banca y Finanzas',
 'SECRETARIA DE TURISMO':'Servicios',
 'COMISION DE OPERACION Y FOMENTO DE ACTIVIDADES ACADEMICAS DEL INSTITUTO POLITECNICO NACIONAL':'Educación e Investigación',
 'COMISIÓN EJECUTIVA DE ATENCIÓN A VÍCTIMAS':'Seguridad Nacional',
 'IMPRESORA Y ENCUADERNADORA PROGRESO S.A. DE C.V.':'Servicios',
 'INSTITUTO MEXICANO DE LA PROPIEDAD INDUSTRIAL':'Industria',
 'CFE TRANSMISIÓN':'Energía',
 'FIDEICOMISO PROMEXICO':'Banca y Finanzas',
 'HOSPITAL REGIONAL DE ALTA ESPECIALIDAD DE CIUDAD VICTORIA BICENTENARIO 2010':'Salud',
 'FIDEICOMISO DE FOMENTO MINERO':'Minería',
 'CENTRO DE INVESTIGACION EN ALIMENTACION Y DESARROLLO A.C.':'Salud',
 'INSTITUTO NACIONAL PARA EL FEDERALISMO Y EL DESARROLLO MUNICIPAL':'Economía y Desarrollo',
 'INSTITUTO NACIONAL DE CIENCIAS PENALES':'Educación e Investigación',
 'TRIBUNAL FEDERAL DE CONCILIACION Y ARBITRAJE':'Gobernanza y Justicia',
 'CENTRO NACIONAL DE PLANEACION ANALISIS E INFORMACION PARA EL COMBATE A LA DELINCUENCIA':'Seguridad Nacional',
 'INSTITUTO NACIONAL DE REHABILITACION':'Salud',
 'FONDO ESPECIAL PARA FINANCIAMIENTOS AGROPECUARIOS':'Agricultura',
 'POLICIA FEDERAL':'Seguridad Nacional',
 'PRODUCTORA NACIONAL DE BIOLOGICOS VETERINARIOS':'Educación e Investigación',
 'SERVICIO GEOLOGICO MEXICANO':'Educación e Investigación',
 'EXPORTADORA DE SAL S.A.DE C.V.':'Servicios',
 'SECRETARÍA EJECUTIVA DEL SISTEMA NACIONAL ANTICORRUPCIÓN':'Gobernanza y Justicia',
 'CENTRO DE INVESTIGACION Y DESARROLLO TECNOLOGICO EN ELECTROQUIMICA S.C.':'Educación e Investigación',
 'CENTRO REGIONAL DE ALTA ESPECIALIDAD EN CHIAPAS':'Salud',
 'COLEGIO SUPERIOR AGROPECUARIO DEL ESTADO DE GUERRERO':'Educación e Investigación',
 'FONDO DE EMPRESAS EXPROPIADAS DEL SECTOR AZUCARERO':'Banca y Finanzas',
 'SECRETARIA DE LA DEFENSA NACIONAL':'Seguridad Nacional',
 'INSTITUTO NACIONAL DE MEDICINA GENOMICA':'Salud',
 'PREVENCION Y READAPTACION SOCIAL':'Seguridad Nacional',
 'CENTRO NACIONAL DE METROLOGIA':'Medio Ambiente',
 'INSTITUTO NACIONAL DE NEUROLOGIA Y NEUROCIRUGIA DR. MANUEL VELASCO SUAREZ':'Salud',
 'INSTITUTO DE SEGURIDAD Y SERVICIOS SOCIALES DE LOS TRABAJADORES DEL ESTADO':'Salud',
 'INSTITUTO NACIONAL DE CIENCIAS MEDICAS Y NUTRICION SALVADOR ZUBIRAN (INV)':'Educación e Investigación',
 'CENTRO NACIONAL PARA LA SALUD DE LA INFANCIA Y ADOLESCENCIA':'Salud',
 'FERROCARRIL DEL ISTMO DE TEHUANTEPEC S.A. DE C.V.':'Comunicación y Transporte',
 'FINANCIERA RURAL':'Banca y Finanzas',
 'CIATEQ A.C. CENTRO DE TECNOLOGIA AVANZADA':'Educación e Investigación',
 'INSTITUTO POTOSINO DE INVESTIGACION CIENTIFICA Y TECNOLOGICA A.C.':'Educación e Investigación',
 'SECRETARIADO EJECUTIVO DEL SISTEMA NACIONAL ANTICORRUPCIÓN':'',
 'INSTITUTO NACIONAL DE LA ECONOMÍA SOCIAL':'Economía y Desarrollo',
 'COLEGIO DE POSTGRADUADOS':'Educación e Investigación',
 'SECRETARIA GENERAL DEL CONSEJO NACIONAL DE POBLACION':'Educación e Investigación',
 'INSTITUTO NACIONAL DE LA PESCA':'Agricultura',
 'SERVICIO DE ADMINISTRACION Y ENAJENACION DE BIENES':'Banca y Finanzas',
 'COMISION FEDERAL DE ELECTRICIDAD':'Energía',
 'FONDO NACIONAL DE FOMENTO AL TURISMO':'Servicios',
 'INSTITUTO DE INVESTIGACIONES ELECTRICAS':'Educación e Investigación',
 'CENTRO NACIONAL DE PREVENCION DE DESASTRES':'Banca y Finanzas',
 'EL COLEGIO DE LA FRONTERA NORTE A.C.':'Educación e Investigación',
 'CENTRO DE ENSEÑANZA TECNICA INDUSTRIAL.':'Educación e Investigación',
 'UNIVERSIDAD ABIERTA Y A DISTANCIA DE MÉXICO':'Educación e Investigación',
 'FONATUR PRESTADORA DE SERVICIOS S.A. DE C.V.':'Servicios',
 'PROCURADURIA FEDERAL DEL CONSUMIDOR':'Economía y Desarrollo',
 'CENTRO DE PRODUCCION DE PROGRAMAS INFORMATIVOS Y ESPECIALES':'Educación e Investigación',
 'INSTITUTO NACIONAL DE LAS MUJERES':'Seguridad Nacional',
 'CENTRO DE INVESTIGACION EN GEOGRAFIA Y GEOMATICA ING. JORGE L. TAMAYO A.C.':'Educación e Investigación',
 'PROCURADURIA GENERAL DE LA REPUBLICA':'Seguridad Nacional',
 'COORDINACION GENERAL DE LA COMISION MEXICANA DE AYUDA A REFUGIADOS':'Gobernanza y Justicia',
 'ADMINISTRACION PORTUARIA INTEGRAL DE TOPOLOBAMPO S.A. DE C.V.':'Comunicación y Transporte',
 'LABORATORIOS DE BIOLOGICOS Y REACTIVOS DE MEXICO S.A. DE C.V.':'Educación e Investigación',
 'BANCO DEL AHORRO NACIONAL Y SERVICIOS FINANCIEROS S N C':'Banca y Finanzas',
 'INSTITUTO FEDERAL DE TELECOMUNICACIONES':'Comunicación y Transporte',
 'CIATEC A.C. CENTRO DE INNOVACION APLICADA EN TECNOLOGIAS COMPETITIVAS':'Educación e Investigación',
 'INSTITUTO DE CAPACITACION Y PROFESIONALIZACION EN PROCURACION DE JUSTICIA FEDERAL':'Educación e Investigación',
 'INSTITUTO DEL FONDO NACIONAL PARA EL CONSUMO DE LOS TRABAJADORES':'Salud',
 'SECRETARIA DE GOBERNACION':'Gobernanza y Justicia',
 'FIDEICOMISO FONDO NACIONAL DE HABITACIONES POPULARES':'Banca y Finanzas',
 'INSTITUTO NACIONAL DE DESARROLLO SOCIAL':'Economía y Desarrollo',
 'CENTRO NACIONAL DE CONTROL DE GAS NATURAL':'Energía',
 'CENTROS DE INTEGRACION JUVENIL A.C.':'Salud',
 'FERROCARRILES NACIONALES DE MEXICO':'Comunicación y Transporte',
 'CENTRO NACIONAL PARA LA PREVENCIÓN Y EL CONTROL DE LAS ADICCIONES':'Salud',
 'FONDO DE GARANTIA Y FOMENTO PARA LA AGRICULTURA GANADERIA Y AVICULTURA':'Agricultura',
 'PROCURADURIA FEDERAL DE LA DEFENSA DEL TRABAJO':'Economía y Desarrollo',
 'INSTITUTO POLITECNICO NACIONAL':'Educación e Investigación',
 'TRIBUNALES UNITARIOS AGRARIOS':'Agricultura',
 'CENTRO NACIONAL DE VIGILANCIA EPIDEMIOLOGICA Y CONTRTOL DE ENFERMEDADES':'Salud',
 'CENTRO NACIONAL PARA LA PREVENCION Y CONTROL DEL VIH/SIDA':'Salud',
 'EL COLEGIO DE MICHOACAN A.C.':'Educación e Investigación',
 'UNIVERSIDAD AUTONOMA METROPOLITANA':'Educación e Investigación',
 'CONSEJO NACIONAL PARA LA CULTURA Y LAS ARTES':'Arte y Cultura',
 'INSTITUTO NACIONAL DE LENGUAS INDIGENAS':'Educación e Investigación',
 'SERVICIOS A LA NAVEGACION EN EL ESPACIO AEREO MEXICANO':'Educación e Investigación',
 'ADMINISTRACION PORTUARIA INTEGRAL DE LAZARO CARDENAS S.A. DE C.V.':'Comunicación y Transporte',
 'COMISION NACIONAL DE SEGURIDAD NUCLEAR Y SALVAGUARDIAS':'Seguridad Nacional',
 'P.M.I. COMERCIO INTERNACIONAL S.A. DE C.V.':'Servicios',
 'CENTRO DE EVALUACION Y DESARROLLO HUMANO':'Salud',
 'COMISIÓN NACIONAL DE HIDROCARBUROS':'Energía',
 'Instituto Federal de Telecomunicaciones':'Comunicación y Transporte',
 'Secretaría de la Función Pública':'Gobernanza y Justicia',
 'Secretaría de Hacienda y Crédito Público':'Gasto Público',
 'Fondo de la Vivienda del Instituto de Seguridad y Servicios Sociales de los Trabajadores del Estado ':'Banca y Finanzas'
})

df_2['inhabilitacion'] = df_2['inhabilitacion'].map({'6 años':6,
 '2 años':2,
 '4 años':4,
 '3 años':3,
 '10 años':10,
 '9 años':9,
 '5 años':5,
 '7 años':7,
 '8 años':8,
 '1 años':1,
 '1 mes':0.08,
 '6 meses':0.5
                                        })

# %%
df_2 = df_2.fillna(method ='ffill') 
df_2 = df_2.dropna(axis=0)
print(df_2.shape)
df_2.isnull().sum().sort_values(ascending=False)
# Out:
# (596, 8)
# autoridadSancionadora    0
# sancion                  0
# causa                    0
# dependencia              0
# genero                   0
# puesto                   0
# inhabilitacion           0
# value                    0
# dtype: int64

# %%
df_2.dtypes
# Out:
# autoridadSancionadora     object
# sancion                   object
# causa                     object
# dependencia               object
# genero                    object
# puesto                    object
# inhabilitacion           float64
# value                      int64
# dtype: object

# %%
df_2.head()
# Out:
#        autoridadSancionadora       sancion                        causa  \
# 0        Contraloría Interna  INHABILITADO       TRÁFICO DE INFLUENCIAS
# 1                   Tribunal  INHABILITADO       ENRIQUECIMIENTO OCULTO
# 2  Organo de Control Interno    SUSPENSION       TRÁFICO DE INFLUENCIAS
# 3                   Tribunal  INHABILITADO                    NEPOTISMO
# 4                        OIC  INHABILITADO  DESVÍO DE RECURSOS PÚBLICOS
#
#   dependencia  genero                puesto  inhabilitacion  value
# 0     Energía   Mujer  Jefe de departamento             6.0      1
# 1     Energía  Hombre  Jefe de departamento             2.0      1
# 2     Energía  Hombre  Jefe de departamento             6.0      1
# 3     Energía   Mujer  Jefe de departamento             4.0      1
# 4     Energía   Mujer  Jefe de departamento             6.0      1

# %%
df_2.to_csv("inhabilitacion_shiny.csv")
